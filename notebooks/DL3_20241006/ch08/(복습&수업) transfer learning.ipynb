# %% [markdown]
# #전이학습 Transfer learning
#
#   - 학습된 신경망을 다른 쪽으로 옮겨서 끝쪽? 으로?? 다른 모델을 사용, 학습
#   - 장점 : 나머지만 학습하면 됨. 컴퓨팅 파워가 강하지 않아도 됨
#
#
# ![alt text](image.png)
#
#
# ### ResNet 사전학습된 신경망
#
#  - 인간보다 나은 최초의 신경망
#  - ResNet 30 50 등 뒤에 숫자가 붙음 layer 개수을 의미함~~
#
#  ![alt text](image-1.png)
#
#
#  ![alt text](image-2.png)
#  ![alt text](image-3.png)
